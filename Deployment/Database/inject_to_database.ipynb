# %%
# import pandas as pd
# from sqlalchemy import create_engine

# df = pd.read_excel(r"C:\Rizki Others\Upwork\Internal Audit Database Project\Outputs\Audit_Types_enriched_gpt5.xlsx")

# DB_URL = "postgresql+psycopg2://audit_user:secret@localhost:5432/audit_db"

# engine = create_engine(DB_URL)

# df.columns = [c.lower().replace(" ", "_") for c in df.columns]

# df.to_sql("audit_types", engine, if_exists="append", index=False)

# print("Import completed.")

# %%
# import pandas as pd
# from sqlalchemy import create_engine

# df = pd.read_excel(r"C:\Rizki Others\Upwork\Internal Audit Database Project\Outputs\Audit_Types_enriched_gpt5.xlsx")

# # Clean column names correctly
# df.columns = (
#     df.columns
#       .str.strip()
#       .str.lower()
#       .str.replace(" ", "_")
# )

# # Debug check
# print("Columns:", df.columns.tolist())

# engine = create_engine(
#     "postgresql+psycopg2://audit_user:secret@localhost:5432/audit_db"
# )

# df.to_sql(
#     "audit_types",
#     engine,
#     if_exists="append",
#     index=False,
#     method="multi"   # faster bulk insert
# )

# print("✅ Data inserted successfully")
# Out:
# Columns: ['internal_audit', 'sector', 'family', 'category', 'type_of_audit', 'description', 'when_to_use', 'framework_or_criteria']
# ✅ Data inserted successfully
